# %% [markdown]
# # Data Wrangling, I
#
#                                                  -By Aditya Nikam(TE AI & DS)
#
# Perform the following operations using Python on dataset(e.g.,
# employee.csv)
#
# 1.Import all the required Python Libraries. And Load the Dataset into pandas data frame.
#
# 2.Data Preprocessing: find the missing values in the data columnwise and display statistical information.
#
# 3.Provide variable descriptions. Types of variables etc.Check the dimensions of the data frame
#
# 4.Data Formatting Summarize the types of variables by checking the data types (i.e., character, numeric, integer, factor, and logical) of the variables in the data set. If variables are not in the correct data type, apply proper type
# conversions.
#
# 5.Data Normalization:Perform Z-Score transformation and plot box plot for
# any column
#
# 6.Turn categorical variables into quantitative variables in Python.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')#we use this to ignore the warnings means in the output warnings should not appear
# Out:
# C:\Users\champ\PycharmProjects\Tutorials\a\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\champ\PycharmProjects\Tutorials\a\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Loading the dataset

# %%
df=pd.read_csv(r"C:\Users\champ\Downloads\employees.csv")#this is to import the dataset.
#The dataset is a csv file.df is the name given to the dataset
df#this is written to display the dataset
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df.head()#it display the first five rows of the dataset.Its default value is 5
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.head(10)#Now as we have entered 10 in the brackets so it will show the first 10 records in the dataset
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
df.tail()#it shows the last five records in the dataset.Its default value is 5
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales

# %%
df.isnull()#here wherever False is written means it is a non null value
#if True is written then that indicates that there is null value present there
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
df.isnull().sum()#This displays the number of null values in each column
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df.notnull().sum()#it display the number of non null values in each column
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %%
df.notnull()#here in dataframe wherever True is written that indicates that it is a non null value
#if False is written then that is a null value
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0          True    True        True             True    True     True
# 1          True    True        True             True    True     True
# 2          True    True        True             True    True     True
# 3          True    True        True             True    True     True
# 4          True    True        True             True    True     True
# ..          ...     ...         ...              ...     ...      ...
# 995        True   False        True             True    True     True
# 996        True    True        True             True    True     True
# 997        True    True        True             True    True     True
# 998        True    True        True             True    True     True
# 999        True    True        True             True    True     True
#
#      Senior Management   Team
# 0                 True   True
# 1                 True  False
# 2                 True   True
# ...

# %%
df.shape#it tells the number of rows and columns in the dataset so here are 1000 rows and 8 columns
# Out:
# (1000, 8)

# %%
df.describe()#it gives the statistical information of the numeric columns of the dataset
#Like in our dataset Salary and Bonus % have numeric values so df.describe() gives their mean,std,min,max values etc
#Like the salary column has the mean of 90662.18100 Bonus has mean of 10.20755
#Minimum value in Salary column is 35013.000 and Bonus % minimum value is 1.015000
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df.size#it displays the multiplication result of rows and columns in the dataset so here 1000*8=8000
# Out:
# 8000

# %% [markdown]
# # Data Formating

# %%
df.info()#It gives the summary of the dataframe and it tells how many non null values are there in each column,what 
#is the data type of each coloumn,how many columns are there in the dataset
#Here we can see that in our dataset there are 8 coloumns where 6 columns have object Datatype
#1 column have float data type and 1 column has integer datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
#If you see the dataset you see that Bonus % column has floating values but we want in into be integer only 
#and convert Start Date data type t0 datetime format means here we are doing type conversion
df["Bonus %"]=df["Bonus %"].astype(int)#converting the data type of Bonus % from float to integer 
df["Start Date"]=df["Start Date"].astype('datetime64[ns]')#converting data type of Start Date from object
# to datetime format
df["Last Login Time"]=df["Last Login Time"].astype('datetime64[ns]')#converting data type of Last Login Time from object
# to datetime format
#Note that whenever there is a column related to date or time then it should have data type as datetime64[ns]
df["Senior Management"]=df["Senior Management"].astype('bool')#As we seen in dataset that the values in Senior Management
#column are True and False so Senior Management column should have data type of boolean instead of object so we are 
#converting object data type into boolean 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   int32
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), int32(1), int64(1), object(3)
# memory usage: 51.9+ KB

# %%
df#You will see the changes reflected in the dataset as you have converted the data types
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2025-04-30 12:42:00   97308        6
# 1       Thomas    Male 1996-03-31 2025-04-30 06:53:00   61933        4
# 2        Maria  Female 1993-04-23 2025-04-30 11:17:00  130590       11
# 3        Jerry    Male 2005-03-04 2025-04-30 13:00:00  138705        9
# 4        Larry    Male 1998-01-24 2025-04-30 16:47:00  101004        1
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2025-04-30 06:09:00  132483       16
# 996    Phillip    Male 1984-01-31 2025-04-30 06:30:00   42392       19
# 997    Russell    Male 2013-05-20 2025-04-30 12:39:00   96914        1
# 998      Larry    Male 2013-04-20 2025-04-30 16:45:00   60500       11
# 999     Albert    Male 2012-05-15 2025-04-30 18:24:00  129949       10
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# # Data Normalization using Z Score

# %%
#Z-score is a normalization technique which tells the distribution of the data in the dataset means it calcuates the mean
#and standard deviation of the numeric columns and then calculates the z score.Basically it tells that how far are values
#of that particular colum(where we have applied Z score normalization)from the average of that column
#Z score centers the values near to zero and it helps to detects the outliers in the dataset
#The formula to calculate z score is  
#                            z score=(x−μ)/σ
#where x is the value in that particular column and μ is the mean of that particular column and σ is standard
#deviation of that particular column
                                
from sklearn.preprocessing import StandardScaler#standard scaler is a tool from sci-kit learn library which helps in 
#normalization of the data
numeric_cols = ['Salary', 'Bonus %']#we can only do normalization of numeric columns so in our dataset there are only 
#two numeric columns which are Salary and Bonus %
scaler = StandardScaler()#creating the object of Standard Scaler
# Apply Z-score normalization
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])#fit removes the mean and Standard deviation of Salary and Bonus %
#column and transform calculates the z score 
# Display updated value
df
#Like for example in Salary column you will see that now first value is 0.201956 now lets understand how these value was 
#removed now we know that mean(average)of the salary column is 90662.181(from df.describe()command which is written above)
#and in dataset before applying the z score normalization the first value of Salary column was 97308 which is the value of x
#here and we also get to know the standard deviation of Salary column(from df.describe() command which is written above)
#standard deviation of Salary column is 32923.693342 so we calculate z score as (97308-90662.181)/32923.693342 which comes
#out to to 0.201956
#so same thing is done for each value of the Salary column and the Bonus % column
#If the z score value is positive then the original value(means value before applying z score)in dataset was above average 
#of the column and if the z score value is negative then the original value was below average of the column
# Out:
#     First Name  Gender Start Date     Last Login Time    Salary   Bonus %  \
# 0      Douglas    Male 1993-08-06 2025-04-30 12:42:00  0.201956 -0.671864
# 1       Thomas    Male 1996-03-31 2025-04-30 06:53:00 -0.873036 -1.034056
# 2        Maria  Female 1993-04-23 2025-04-30 11:17:00  1.213345  0.233613
# 3        Jerry    Male 2005-03-04 2025-04-30 13:00:00  1.459947 -0.128578
# 4        Larry    Male 1998-01-24 2025-04-30 16:47:00  0.314272 -1.577342
# ..         ...     ...        ...                 ...       ...       ...
# 995      Henry     NaN 2014-11-23 2025-04-30 06:09:00  1.270870  1.139091
# 996    Phillip    Male 1984-01-31 2025-04-30 06:30:00 -1.466857  1.682378
# 997    Russell    Male 2013-05-20 2025-04-30 12:39:00  0.189983 -1.577342
# 998      Larry    Male 2013-04-20 2025-04-30 16:45:00 -0.916582  0.233613
# 999     Albert    Male 2012-05-15 2025-04-30 18:24:00  1.193866  0.052518
#
#      Senior Management                  Team
# ...

# %%
df.describe()
# Out:
#                 Start Date             Last Login Time        Salary  \
# count                 1000                        1000  1.000000e+03
# mean   1998-12-12 21:50:24  2025-04-30 11:52:48.900000  1.003642e-16
# min    1980-01-19 00:00:00         2025-04-30 00:00:00 -1.691093e+00
# 25%    1990-07-21 12:00:00         2025-04-30 06:01:00 -8.523714e-01
# 50%    1999-07-16 00:00:00         2025-04-30 12:04:00 -7.116400e-03
# 75%    2007-09-30 12:00:00         2025-04-30 17:55:45  8.532493e-01
# max    2016-07-15 00:00:00         2025-04-30 23:59:00  1.800389e+00
# std                    NaN                         NaN  1.000500e+00
#
#             Bonus %
# count  1.000000e+03
# mean  -1.421085e-16
# min   -1.577342e+00
# 25%   -8.529600e-01
# 50%   -1.285778e-01
# 75%    7.768999e-01
# max    1.682378e+00
# std    1.000500e+00

# %%
import matplotlib.pyplot as plt#used for plotting basic graphs
import seaborn as sns#used to make plot attractive
# Create a box plot for normalized Salary
plt.figure(figsize=(6, 4))#this sets the size of the plot.Here we have taken size as 6 inches wide and 4 inches tall
sns.boxplot(y=df['Salary'])#We are plotting box plot for Salary column and it will be vertical as we have written y=
#if I had written x= then it will be horizontal
plt.title('Box Plot of Salary')#This is the title of the plot
plt.ylabel('Z-score')#We are adding label in y axis named "Z-score".
plt.grid(True)#to show grids in the graph
plt.show()#to display the plot
#Now in this box plot there are now outliers so you will not see any outliers
#Now you will wonder that we have some z score values above 1.0 or -1.0 but in box plot the blue part is between 0.5 ans 1 
#only the reason being that box plot plots the IQR Range means the 75% and 25%
#you see in the above df.describe()command that 25%(Q1)after Z score is -8.523714e-01 means-8.523714x10^-1 which actually 
#means its actually -0.8523714 and similarly for Q3(75%)which is 8.532493e-01 means 0.8523493 so box plot plots these values
#the lower bound(Q1)is -0.8523714 so blue part of the box plot ends between -0.5 and -1 as Q1 value(lower bound) value 
#is -0.852371 similarly for Q3

#we have written z-score in y axis because we are plotting the IQR range of z-score of Salary column
#There are no outliers in our box plot because they are no extreme or very different(outliers) z score values in our 
#dataset for Salary column

#We will see outliers only if there were z score values in Salary column above 3.41 or-3.409 
#I have shown how below how 3.41 or -3.409 have come
#Q1 ≈ -0.852(from df.describe()command above)
#Q3 ≈ +0.853(from df.describe()command above)
#→IQR = Q3 − Q1 ≈ 1.705
#Lower bound =-0.852−1.5×1.705=-3.409(Lower Bound=Q1-1.5*IQR this is the formula)
#Upper bound=+0.853+1.5×1.705=+3.419(Upper Bound=Q3-1.5*IQR this is the formula)

# %% [markdown]
# # Converting Categorical Values into Numerical Values

# %%
df["Gender"]=df["Gender"].replace({"Female":0,"Male":1})#converting categorical data into numerical by assigning zero 
#to female and 1 to male
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time    Salary   Bonus %  \
# 0    Douglas     1.0 1993-08-06 2025-04-30 12:42:00  0.201956 -0.671864
# 1     Thomas     1.0 1996-03-31 2025-04-30 06:53:00 -0.873036 -1.034056
# 2      Maria     0.0 1993-04-23 2025-04-30 11:17:00  1.213345  0.233613
# 3      Jerry     1.0 2005-03-04 2025-04-30 13:00:00  1.459947 -0.128578
# 4      Larry     1.0 1998-01-24 2025-04-30 16:47:00  0.314272 -1.577342
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
#Now as you can see that Gender Column has values 1.0 and 0.0 means floating values and data type of of Gender is 
#float and you want to convert it into integer so you will try to convert data type 
#of Gender but if you write the command df["Gender"]=df["Gender"].astype('int') you will
#get an error try it
#the reason for this is that we have null values in Gender column and we cannot convert null values into int data type
#If we wanted to convert to data type of Gender from float to any other data type instead of int there will be no error
#Because only int cant work with null values
#So drop the missing values from the dataset/from the Gender column or fill it we will drop null values from entire dataset
#using dropna() method
df=df.dropna()#dropna() method will remove the rows which contain atleast one null value
#Now write 
df.info()#we will see that all null values rows are dropped from the dataset and we are left with 764 rows now 
#instead of 1000
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    float64
#  2   Start Date         764 non-null    datetime64[ns]
#  3   Last Login Time    764 non-null    datetime64[ns]
#  4   Salary             764 non-null    float64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    bool
#  7   Team               764 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(3), object(2)
# memory usage: 48.5+ KB

# %%
df["Gender"]=df["Gender"].astype('int')
df.info()#Now you see that no error is there and the data type is also converted
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    int32
#  2   Start Date         764 non-null    datetime64[ns]
#  3   Last Login Time    764 non-null    datetime64[ns]
#  4   Salary             764 non-null    float64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    bool
#  7   Team               764 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(2), int32(1), object(2)
# memory usage: 45.5+ KB

# %%
df#Now changes will be reflected in the dataset and you will see the Gender column now has integer values instead
#of float
# Out:
#     First Name  Gender Start Date     Last Login Time    Salary   Bonus %  \
# 0      Douglas       1 1993-08-06 2025-04-30 12:42:00  0.201956 -0.671864
# 2        Maria       0 1993-04-23 2025-04-30 11:17:00  1.213345  0.233613
# 3        Jerry       1 2005-03-04 2025-04-30 13:00:00  1.459947 -0.128578
# 4        Larry       1 1998-01-24 2025-04-30 16:47:00  0.314272 -1.577342
# 5       Dennis       1 1987-04-18 2025-04-30 01:35:00  0.744542  0.052518
# ..         ...     ...        ...                 ...       ...       ...
# 994     George       1 2013-06-21 2025-04-30 17:47:00  0.249545 -1.034056
# 996    Phillip       1 1984-01-31 2025-04-30 06:30:00 -1.466857  1.682378
# 997    Russell       1 2013-05-20 2025-04-30 12:39:00  0.189983 -1.577342
# 998      Larry       1 2013-04-20 2025-04-30 16:45:00 -0.916582  0.233613
# 999     Albert       1 2012-05-15 2025-04-30 18:24:00  1.193866  0.052518
#
#      Senior Management                  Team
# ...
